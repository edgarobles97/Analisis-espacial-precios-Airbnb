# %%
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import os

# %%
px.set_mapbox_access_token('pk.eyJ1IjoiZWRnYXJvYmxlczk3IiwiYSI6ImNraTR3bWw0NDA1anAydG1zYzg3dGx1bmoifQ.pKVBb-bWQqiYcn6f9QPbFQ')

# %%
os.getcwd()
# Out:
# '/Users/edgar_oficial/analytics/sandbox/Analisis-espacial-precios-Airbnb/notebooks'

# %%
data = pd.read_csv('inside_abnb_clean_4.csv', encoding='latin1')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6131 entries, 0 to 6130
# Data columns (total 43 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         6131 non-null   int64
#  1   index                      6131 non-null   int64
#  2   host_is_superhost          6131 non-null   int64
#  3   host_total_listings_count  6131 non-null   int64
#  4   host_identity_verified     6131 non-null   int64
#  5   colonia                    5452 non-null   object
#  6   alcaldía                   6131 non-null   object
#  7   código_postal              6052 non-null   object
#  8   latitude                   6131 non-null   float64
#  9   longitude                  6131 non-null   float64
#  10  accommodates               6131 non-null   int64
#  11  bathrooms                  6131 non-null   float64
#  12  bedrooms                   6131 non-null   int64
# ...

# %%
data.head()
# Out:
#        id  index  host_is_superhost  host_total_listings_count  \
# 0   58955     17                  0                          1
# 1   67703     44                  1                          4
# 2   70644     80                  1                          4
# 3  171109    104                  1                          2
# 4  180808    141                  1                          2
#
#    host_identity_verified     colonia       alcaldía código_postal  latitude  \
# 0                       1  Roma Norte     Cuauhtémoc          6700  19.42292
# 1                       1   Hipódromo     Cuauhtémoc          6100  19.41375
# 2                       1    Coyoacán       Coyoacán          4100  19.35601
# 3                       0     Nápoles  Benito Juárez           NaN  19.39549
# 4                       1      Juárez     Cuauhtémoc          6600  19.42428
#
#    longitude  ...  pool  smoking_allowed  hot_tub  ad_duration  \
# ...

# %%
# Cambia solo el nombre de la función
fig = px.scatter_map(  # <-- OJO AQUÍ: scatter_map (sin "box")
    data,
    lat='latitude',
    lon='longitude',
    color='Entire home/apt',
    size='precio',
    size_max=30,
    zoom=10  # Agregué zoom para que no empiece desde el espacio exterior
)
fig.show()
